# %%
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:13<00:00, 1.91MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 97.0kB/s]
# 100%|██████████| 4.42M/4.42M [00:06<00:00, 686kB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 4.23MB/s]

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_data), size=(1,)).item()
    img, label = training_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
training_data??
# Out:
# Type:        FashionMNIST
# String form:
# Dataset FashionMNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()
# Length:      60000
# File:        ~/Documents/.venv/lib/python3.12/site-packages/torchvision/datasets/mnist.py
# Source:
# class FashionMNIST(MNIST):
#     """`Fashion-MNIST <https://github.com/zalandoresearch/fashion-mnist>`_ Dataset.
#
#     Args:
#         root (str or ``pathlib.Path``): Root directory of dataset where ``FashionMNIST/raw/train-images-idx3-ubyte``
#             and  ``FashionMNIST/raw/t10k-images-idx3-ubyte`` exist.
#         train (bool, optional): If True, creates dataset from ``train-images-idx3-ubyte``,
#             otherwise from ``t10k-images-idx3-ubyte``.
#         transform (callable, optional): A function/transform that  takes in a PIL image
#             and returns a transformed version. E.g, ``transforms.RandomCrop``
# ...

# %%
test_data??
# Out:
# Type:        FashionMNIST
# String form:
# Dataset FashionMNIST
#     Number of datapoints: 10000
#     Root location: data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()
# Length:      10000
# File:        ~/Documents/.venv/lib/python3.12/site-packages/torchvision/datasets/mnist.py
# Source:
# class FashionMNIST(MNIST):
#     """`Fashion-MNIST <https://github.com/zalandoresearch/fashion-mnist>`_ Dataset.
#
#     Args:
#         root (str or ``pathlib.Path``): Root directory of dataset where ``FashionMNIST/raw/train-images-idx3-ubyte``
#             and  ``FashionMNIST/raw/t10k-images-idx3-ubyte`` exist.
#         train (bool, optional): If True, creates dataset from ``train-images-idx3-ubyte``,
#             otherwise from ``t10k-images-idx3-ubyte``.
#         transform (callable, optional): A function/transform that  takes in a PIL image
#             and returns a transformed version. E.g, ``transforms.RandomCrop``
# ...

# %%
print(len(training_data))
print(type(training_data[0]))
print(training_data[0])
# Out:
# 60000
# <class 'tuple'>
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#           0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
# ...

# %%
from torch.utils.data import DataLoader

loader = DataLoader(training_data, batch_size=1) #Check the shape of the data
images, labels = next(iter(loader))

print(images.shape)  
print(labels.shape)
# Out:
# torch.Size([1, 1, 28, 28])
# torch.Size([1])

# %%
import os
path = '/home/malceid/Documents/Coding Projects/MNISTResnet/mnist.ipynb'
print(os.dir.exists(path))
# Out:
# True

# %%
os.path.isdir('/home/malceid/Documents/Coding Projects/MNISTResnet/model/tensorboard_logs/')
# Out:
# True

# %%
os.path.isdir('/home/malceid/Documents/Coding Projects/MNISTResnet/model/best_model')
# Out:
# True

# %%
import modal

print(dir(modal.Image))
# Out:
# ['__annotations__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_mount_layer_or_copy', '_assert_no_mount_layers', '_copy_mount', '_from_args', '_from_loader', '_get_metadata', '_get_type_from_id', '_hydrate', '_hydrate_from_other', '_hydrate_metadata', '_init', '_initialize_from_empty', '_initialize_from_other', '_is_id_type', '_logs', '_mount_layers', '_new_hydrated', '_registry_setup_commands', '_repr', '_sync_original_131256371203968', '_sync_synchronizer', '_unhydrate', '_validate_is_hydrated', 'add_local_dir', 'add_local_file', 'add_local_python_source', 'apt_install', 'build', 'client', 'clone', 'cmd', 'debian_slim', 'deps', 'dockerfile_commands', 'entrypoint', '
# ...
